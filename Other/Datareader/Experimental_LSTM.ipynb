# %%
import numpy as np
import pandas as pd
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_datareader as pdr
import itertools
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
sec = pdr.get_data_google('IBM', '2000-01-01', '2017-12-29')

# %%
sec.head()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2002-02-12  106.75  107.89  106.06  106.57   4506200
# 2002-02-13  106.70  108.48  106.12  108.07   5076800
# 2002-02-14  109.00  109.15  107.20  107.89   5756500
# 2002-02-15  104.80  104.80  101.70  102.89  18127600
# 2002-02-19  101.50  101.80   98.86   99.54  13369500

# %%
sec.tail()
# Out:
#               Open    High     Low   Close   Volume
# Date
# 2017-12-22  151.82  153.00  151.50  152.50  2990583
# 2017-12-26  152.51  153.86  152.50  152.83  2479017
# 2017-12-27  152.95  153.18  152.61  153.13  2149257
# 2017-12-28  153.20  154.12  153.20  154.04  2687624
# 2017-12-29  154.17  154.72  153.42  153.42  3327087

# %%
sec.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
sec['Close'].pct_change(1).describe()
# Out:
# count    3999.000000
# mean        0.000195
# std         0.014413
# min        -0.101183
# 25%        -0.006559
# 50%         0.000112
# 75%         0.007056
# max         0.115150
# Name: Close, dtype: float64

# %%
sec_ret = sec['Close'].pct_change(1)

# %%
sec_stdev = sec_ret.rolling(5).std()

# %%
sec_ret_W = sec['Close'].pct_change(5)

# %%
sharpe_W = sec_ret_W / sec_stdev

# %%
sharpe_W
# Out:
# Date
# 2002-02-12         NaN
# 2002-02-13         NaN
# 2002-02-14         NaN
# 2002-02-15         NaN
# 2002-02-19         NaN
# 2002-02-20   -2.742994
# 2002-02-21   -5.476682
# 2002-02-22   -3.220702
# 2002-02-25   -1.992624
# 2002-02-26   -1.299638
# 2002-02-27   -0.774941
# 2002-02-28    1.484164
# 2002-03-01    1.955027
# 2002-03-04    3.217244
# 2002-03-05    4.056647
# 2002-03-06    3.981558
# 2002-03-07    1.997995
# 2002-03-08    1.035228
# 2002-03-11   -0.438995
# 2002-03-12    1.331310
# 2002-03-13    0.383547
# 2002-03-14    1.638013
# 2002-03-15    0.981349
# 2002-03-18    0.626824
# 2002-03-19   -1.083151
# 2002-03-20   -1.463626
# 2002-03-21    0.135171
# 2002-03-22   -0.830302
# 2002-03-25   -1.689322
# 2002-03-26   -3.339632
#                 ...
# 2017-11-16   -0.770091
# 2017-11-17   -0.132310
# 2017-11-20    1.403117
# 2017-11-21    1.942909
# 2017-11-22    4.586952
# 2017-11-24    3.140233
# 2017-11-27    3.688412
# 2017-11-28    3.098631
# ...

# %%
sharpe_W.resample('W-FRI').mean().tail()
# Out:
# Date
# 2017-12-01    4.750390
# 2017-12-08    2.346833
# 2017-12-15   -0.193387
# 2017-12-22   -1.452339
# 2017-12-29    0.859478
# Freq: W-FRI, Name: Close, dtype: float64

# %%
sharpe_W.resample('W').mean().tail()
# Out:
# Date
# 2017-12-03    4.750390
# 2017-12-10    2.346833
# 2017-12-17   -0.193387
# 2017-12-24   -1.452339
# 2017-12-31    0.859478
# Freq: W-SUN, Name: Close, dtype: float64

# %%
[(year, round(sec['Close'].loc[str(year)].pct_change(1).mean()*252*100, 1), round(sec['Close'].loc[str(year)].pct_change(1).std()*(252**0.5)*100, 1)) for year in range(2002,2018)]
# Out:
# [(2002, -26.4, 43.9),
#  (2003, 16.7, 23.1),
#  (2004, 8.5, 14.9),
#  (2005, -15.8, 17.7),
#  (2006, 18.0, 14.3),
#  (2007, 12.8, 20.5),
#  (2008, -15.4, 36.0),
#  (2009, 44.4, 27.6),
#  (2010, 11.9, 17.9),
#  (2011, 24.7, 22.5),
#  (2012, 4.1, 16.2),
#  (2013, -2.9, 18.5),
#  (2014, -13.1, 17.2),
#  (2015, -14.1, 21.3),
#  (2016, 22.0, 19.8),
#  (2017, -7.4, 15.8)]

# %%
sec['Close'].pct_change(1).shift(-1)
# Out:
# Date
# 2002-02-12    0.014075
# 2002-02-13   -0.001666
# 2002-02-14   -0.046343
# 2002-02-15   -0.032559
# 2002-02-19   -0.002311
# 2002-02-20   -0.029504
# 2002-02-21    0.021477
# 2002-02-22   -0.001524
# 2002-02-25   -0.011699
# 2002-02-26    0.006999
# 2002-02-27    0.002964
# 2002-02-28    0.049939
# 2002-03-01    0.027956
# 2002-03-04   -0.002172
# 2002-03-05    0.005962
# 2002-03-06   -0.024365
# 2002-03-07    0.013306
# 2002-03-08    0.001427
# 2002-03-11    0.030977
# 2002-03-12   -0.012166
# 2002-03-13   -0.005411
# 2002-03-14    0.001782
# 2002-03-15   -0.004120
# 2002-03-18    0.010719
# 2002-03-19   -0.018513
# 2002-03-20    0.012133
# 2002-03-21   -0.011051
# 2002-03-22   -0.019318
# 2002-03-25   -0.006373
# 2002-03-26    0.004762
#                 ...
# 2017-11-16   -0.001006
# 2017-11-17    0.010338
# 2017-11-20    0.009567
# 2017-11-21   -0.001185
# 2017-11-22    0.000461
# 2017-11-24    0.000922
# 2017-11-27    0.003224
# 2017-11-28    0.007083
# ...

# %%
sec.rolling(5).mean()
# Out:
#                Open     High      Low    Close      Volume
# Date
# 2002-02-12      NaN      NaN      NaN      NaN         NaN
# 2002-02-13      NaN      NaN      NaN      NaN         NaN
# 2002-02-14      NaN      NaN      NaN      NaN         NaN
# 2002-02-15      NaN      NaN      NaN      NaN         NaN
# 2002-02-19  105.750  106.424  103.988  104.992   9367320.0
# 2002-02-20  104.308  104.916  102.176  103.540  11345100.0
# 2002-02-21  102.718  103.160  100.152  101.202  12322840.0
# 2002-02-22  100.194  101.170   97.864   99.314  13224940.0
# 2002-02-25   98.924  100.060   96.948   98.396  11546420.0
# 2002-02-26   98.424   99.538   96.374   97.918  11174700.0
# 2002-02-27   98.136   99.530   96.314   97.622  10655700.0
# 2002-02-28   98.084   99.510   96.678   97.970  10222500.0
# 2002-03-01   98.528  100.290   97.226   98.884  10240340.0
# 2002-03-04   99.508  101.748   98.428  100.404  10405740.0
# 2002-03-05  100.558  103.210  100.062  102.108   9608460.0
# ...
