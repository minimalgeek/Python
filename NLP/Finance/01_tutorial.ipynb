# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import pandas_datareader as pdr
import datetime

# %%
aapl = pdr.get_data_google('AAPL', 
                          start=datetime.datetime(2006, 10, 1), 
                          end=datetime.datetime(2012, 1, 1))

# %%
import time
for i in range(10):
    print(pdr.get_quote_google('AAPL'))
    time.sleep(0.5)
# Out:
#       change_pct    last                time
# AAPL         0.0  150.08 2017-07-18 16:00:00
#       change_pct    last                time
# AAPL         0.0  150.08 2017-07-18 16:00:00
#       change_pct    last                time
# AAPL         0.0  150.08 2017-07-18 16:00:00
#       change_pct    last                time
# AAPL         0.0  150.08 2017-07-18 16:00:00
#       change_pct    last                time
# AAPL         0.0  150.08 2017-07-18 16:00:00
#       change_pct    last                time
# AAPL         0.0  150.08 2017-07-18 16:00:00
#       change_pct    last                time
# AAPL         0.0  150.08 2017-07-18 16:00:00
#       change_pct    last                time
# AAPL         0.0  150.08 2017-07-18 16:00:00
#       change_pct    last                time
# AAPL         0.0  150.08 2017-07-18 16:00:00
#       change_pct    last                time
# AAPL         0.0  150.08 2017-07-18 16:00:00

# %%
aapl.head()
# Out:
#              Open   High    Low  Close     Volume
# Date
# 2006-10-02  10.73  10.84  10.61  10.69  178263043
# 2006-10-03  10.64  10.71  10.46  10.58  197724611
# 2006-10-04  10.59  10.78  10.45  10.77  209840785
# 2006-10-05  10.65  10.88  10.59  10.69  170994999
# 2006-10-06  10.63  10.72  10.54  10.60  116749486

# %%
aapl.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  1322.000000  1322.000000  1322.000000  1322.000000  1.322000e+03
# mean     28.897012    29.234463    28.503268    28.885348  1.885441e+08
# std      14.127249    14.202423    14.033172    14.124514  1.029074e+08
# min      10.490000    10.570000    10.370000    10.460000  3.941499e+07
# 25%      17.460000    17.752500    17.182500    17.430000  1.122079e+08
# 50%      25.215000    25.620000    24.715000    25.115000  1.631520e+08
# 75%      38.807500    39.187500    38.370000    38.705000  2.321660e+08
# max      60.250000    60.960000    59.430000    60.320000  8.432640e+08

# %%
aapl['Close'].plot(grid=True)

# %%
aapl.loc['2008-10'].head()
# Out:
#              Open   High    Low  Close     Volume
# Date
# 2008-10-01  15.99  16.05  15.34  15.59  324348157
# 2008-10-02  15.43  15.54  14.29  14.30  402629654
# 2008-10-03  14.86  15.21  13.52  13.87  574900179
# 2008-10-06  13.14  14.11  12.51  14.02  526957473
# 2008-10-07  14.35  14.50  12.71  12.74  470441839

# %%
aapl.loc[pd.Timestamp('2006-12-05'):pd.Timestamp('2006-12-31')].tail()
# Out:
#              Open   High    Low  Close     Volume
# Date
# 2006-12-22  11.92  12.01  11.66  11.74  153402130
# 2006-12-26  11.74  11.80  11.56  11.64  122782926
# 2006-12-27  11.16  11.71  10.97  11.65  485160788
# 2006-12-28  11.46  11.61  11.38  11.55  284705848
# 2006-12-29  11.99  12.20  11.91  12.12  269210753

# %%
aapl.sample(10)
# Out:
#              Open   High    Low  Close     Volume
# Date
# 2010-06-04  36.89  37.41  36.38  36.57  189610442
# 2009-06-01  19.50  20.00  19.43  19.91  113166984
# 2007-01-25  12.44  12.64  12.29  12.32  226758903
# 2009-02-03  13.13  13.34  12.90  13.28  149860816
# 2008-04-18  22.73  23.18  22.63  23.01  256639551
# 2007-09-19  20.43  20.45  19.91  20.11  256719848
# 2008-02-22  17.50  17.50  16.55  17.07  382301514
# 2007-07-12  19.12  19.18  18.91  19.15  176151549
# 2010-09-01  35.35  35.92  35.18  35.76  174258805
# 2009-08-11  23.38  23.48  23.13  23.26   88872154

# %%
aapl.resample('BMS').mean()[10:20] # Business month start frequency
# Out:
#                  Open       High        Low      Close        Volume
# Date
# 2007-08-01  18.573043  18.863913  18.152174  18.549130  2.648637e+08
# 2007-09-03  20.274211  20.566316  19.993684  20.295789  2.754050e+08
# 2007-10-01  24.503913  24.785652  24.082174  24.544783  2.530281e+08
# 2007-11-01  25.139524  25.571429  24.329524  24.951905  3.119015e+08
# 2007-12-03  27.214000  27.620500  26.816500  27.215000  2.156884e+08
# 2008-01-01  23.128095  23.614762  22.326190  22.909048  4.188100e+08
# 2008-02-01  18.018500  18.319000  17.580000  17.880000  3.108241e+08
# 2008-03-03  18.592500  19.002500  18.285500  18.688000  2.866809e+08
# 2008-04-01  22.525909  22.928182  22.165909  22.598636  2.589966e+08
# 2008-05-01  26.370000  26.696190  25.952381  26.394286  2.213114e+08

# %%
aapl['Close 1day pct'] = aapl.pct_change()['Close']

# %%
aapl[aapl['Close 1day pct'] == aapl['Close 1day pct'].max()]
# Out:
#              Open   High    Low  Close     Volume  Close 1day pct
# Date
# 2008-10-13  14.94  15.79  14.43  15.75  385120190        0.141304

# %%
aapl.fillna(0, inplace=True)

# %%
aapl.head()
# Out:
#              Open   High    Low  Close     Volume  Close 1day pct
# Date
# 2006-10-02  10.73  10.84  10.61  10.69  178263043        0.000000
# 2006-10-03  10.64  10.71  10.46  10.58  197724611       -0.010290
# 2006-10-04  10.59  10.78  10.45  10.77  209840785        0.017958
# 2006-10-05  10.65  10.88  10.59  10.69  170994999       -0.007428
# 2006-10-06  10.63  10.72  10.54  10.60  116749486       -0.008419

# %%
aapl['Close 1day log return'] = np.log(aapl['Close 1day pct'] + 1)

# %%
aapl.head()
# Out:
#              Open   High    Low  Close     Volume  Close 1day pct  \
# Date
# 2006-10-02  10.73  10.84  10.61  10.69  178263043        0.000000
# 2006-10-03  10.64  10.71  10.46  10.58  197724611       -0.010290
# 2006-10-04  10.59  10.78  10.45  10.77  209840785        0.017958
# 2006-10-05  10.65  10.88  10.59  10.69  170994999       -0.007428
# 2006-10-06  10.63  10.72  10.54  10.60  116749486       -0.008419
#
#             Close 1day log return
# Date
# 2006-10-02               0.000000
# 2006-10-03              -0.010343
# 2006-10-04               0.017799
# 2006-10-05              -0.007456
# 2006-10-06              -0.008455

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(20,5))
ax1.plot(aapl['Close 1day pct'])
ax2.plot(aapl['Close 1day log return'])

# %% [markdown]
# ### resample the last business day

# %%
monthly = aapl.resample('BM').apply(lambda x: x[-1])

# %%
monthly.head()
# Out:
#              Open   High    Low  Close     Volume  Close 1day pct  \
# Date
# 2006-10-31  11.64  11.67  11.46  11.58  125413757        0.007833
# 2006-11-30  13.17  13.24  13.01  13.09  217767193       -0.001526
# 2006-12-29  11.99  12.20  11.91  12.12  269210753        0.049351
# 2007-01-31  12.12  12.29  12.05  12.25  214117890        0.002455
# 2007-02-28  11.86  12.23  11.86  12.09  230020119        0.008340
#
#             Close 1day log return
# Date
# 2006-10-31               0.007802
# 2006-11-30              -0.001527
# 2006-12-29               0.048172
# 2007-01-31               0.002452
# 2007-02-28               0.008306

# %%
monthly['Close'].plot()

# %%
aapl['Close 1day pct'].hist(bins=30)

# %%
aapl['Close 1day pct'].describe()
# Out:
# count    1322.000000
# mean        0.001567
# std         0.023990
# min        -0.179039
# 25%        -0.010628
# 50%         0.001638
# 75%         0.014425
# max         0.141304
# Name: Close 1day pct, dtype: float64

# %%
aapl.loc['2008-9']['Close 1day pct'].describe()
# Out:
# count    21.000000
# mean     -0.017351
# std       0.054524
# min      -0.179039
# 25%      -0.034382
# 50%      -0.013986
# 75%       0.006925
# max       0.079787
# Name: Close 1day pct, dtype: float64

# %% [markdown]
# ### cumulative daily rate of return

# %%
aapl['Cumulative daily return'] = (1 + aapl['Close 1day pct']).cumprod()
aapl['Cumulative daily return'][-10:]
# Out:
# Date
# 2011-12-16    5.091674
# 2011-12-19    5.107577
# 2011-12-20    5.290926
# 2011-12-21    5.298410
# 2011-12-22    5.326473
# 2011-12-23    5.390084
# 2011-12-27    5.433115
# 2011-12-28    5.380730
# 2011-12-29    5.413471
# 2011-12-30    5.412535
# Name: Cumulative daily return, dtype: float64

# %%
(1 + aapl.loc['2008-9']['Close 1day pct']).cumprod()
# Out:
# Date
# 2008-09-02    0.980182
# 2008-09-03    0.984723
# 2008-09-04    0.950867
# 2008-09-05    0.944674
# 2008-09-08    0.931462
# 2008-09-09    0.894715
# 2008-09-10    0.894302
# 2008-09-11    0.900495
# 2008-09-12    0.878613
# 2008-09-15    0.827828
# 2008-09-16    0.824938
# 2008-09-17    0.753922
# 2008-09-18    0.791082
# 2008-09-19    0.831131
# 2008-09-22    0.772915
# 2008-09-23    0.748142
# 2008-09-24    0.759290
# 2008-09-25    0.778282
# 2008-09-26    0.756400
# 2008-09-29    0.620974
# 2008-09-30    0.670520
# Name: Close 1day pct, dtype: float64

# %%
aapl['Cumulative daily return'].plot()

# %%
def get(tickers, startdate, enddate):
    def data(ticker):
        return (pdr.get_data_google(ticker, start=startdate, end=enddate))
    datas = map (data, tickers)
    return(pd.concat(datas, keys=tickers, names=['Ticker', 'Date']))

tickers = ['AAPL', 'MSFT', 'IBM', 'GOOG']
all_data = get(tickers, datetime.datetime(2006, 10, 1), datetime.datetime(2012, 1, 1))

# %%
all_data.head()
# Out:
#                     Open   High    Low  Close       Volume
# Ticker Date
# AAPL   2006-10-02  10.73  10.84  10.61  10.69  178263043.0
#        2006-10-03  10.64  10.71  10.46  10.58  197724611.0
#        2006-10-04  10.59  10.78  10.45  10.77  209840785.0
#        2006-10-05  10.65  10.88  10.59  10.69  170994999.0
#        2006-10-06  10.63  10.72  10.54  10.60  116749486.0

# %%
daily_close_px = all_data[['Close']].reset_index().pivot('Date', 'Ticker', 'Close')

# %%
daily_close_px.head()
# Out:
# Ticker       AAPL    GOOG    IBM   MSFT
# Date
# 2006-10-02  10.69  200.52  81.87  27.36
# 2006-10-03  10.58  201.82  81.65  27.37
# 2006-10-04  10.77  207.64  83.10  27.94
# 2006-10-05  10.69  205.70  82.92  27.92
# 2006-10-06  10.60  210.04  83.14  27.87

# %%
daily_pct_change = daily_close_px.pct_change()

# %%
daily_pct_change.hist(bins=20, sharex=True, figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D6396AB860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D639786908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D6397E7748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D6398563C8>]], dtype=object)

# %% [markdown]
# kde = Kernel Density Estimate plot

# %%
pd.scatter_matrix(daily_pct_change, diagonal='kde', alpha=0.5,figsize=(12,12))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D639A631D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D639ECCF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D639EE70B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D639B27198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D639ABC358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D639ABC4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D639F04F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D639F84278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D639FE9208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D63A022B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D63A0AF7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D63A0C1DA0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D63A180278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D63A1CDF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D63A247CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D63A2AC5F8>]], dtype=object)

# %% [markdown]
# # Moving Windows
# ```rolling_mean(), rolling_std(), ...```

# %%
aapl['Close'].rolling(window=100).mean().plot()

# %%
aapl['Close'].rolling(window=100).max().plot()

# %%
aapl['Close'].rolling(window=100).var().plot()

# %%
aapl['Close'].rolling(window=100).median().plot()

# %% [markdown]
# # Volatility calculation
# https://www.datacamp.com/community/tutorials/finance-python-trading#volatility-calculation

# %%
min_periods = 75 
vol = daily_pct_change.rolling(min_periods).std() * np.sqrt(min_periods) 
vol.plot(figsize=(10, 8))

# %%
vol.cumsum()[-1:]
# Out:
# Ticker            AAPL        GOOG         IBM        MSFT
# Date
# 2011-12-30  231.125252  210.594727  160.513797  191.024526

# %% [markdown]
# # Ordinary Least-Squares Regression

# %%
import statsmodels.api as sm
from pandas.core import datetools
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
all_close = all_data[['Close']]

# %%
all_returns = np.log(all_close / all_close.shift(1))

# %%
def calc_returns(ticker):
    returns = all_returns.iloc[all_returns.index.get_level_values('Ticker') == ticker]
    returns.index = returns.index.droplevel('Ticker')
    return returns

# %%
aapl_returns = calc_returns('AAPL')
msft_returns = calc_returns('MSFT')

# %%
return_data = pd.concat([aapl_returns, msft_returns], axis=1)[1:]
return_data.columns = ['AAPL', 'MSFT']

# %%
X = sm.add_constant(return_data['AAPL'])
model = sm.OLS(return_data['MSFT'],X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MSFT   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     516.6
# Date:                Wed, 19 Jul 2017   Prob (F-statistic):           9.08e-97
# Time:                        15:13:18   Log-Likelihood:                 3510.7
# No. Observations:                1321   AIC:                            -7017.
# Df Residuals:                    1319   BIC:                            -7007.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0
# 2011-12-20     1.0   55.456000  55.377300        0.0
# 2011-12-21     1.0   55.451500  55.376900        0.0
# 2011-12-22     1.0   55.444250  55.391700        0.0
# 2011-12-23     1.0   55.439500  55.407100        0.0
# 2011-12-27     0.0   55.445250  55.448800       -1.0
# 2011-12-28     0.0   55.437500  55.490300        0.0
# 2011-12-29     0.0   55.468250  55.564400        0.0
# 2011-12-30     0.0   55.495500  55.608700        0.0
#
# [1322 rows x 4 columns]

# %%
signals[signals['positions'] != 0.0]
# Out:
#             signal  short_mavg  long_mavg  positions
# Date
# 2006-10-02     0.0    10.69000  10.690000        NaN
# 2006-11-28     1.0    11.53675  11.516098        1.0
# 2008-02-06     0.0    24.16450  24.170800       -1.0
# 2008-05-06     1.0    21.76850  21.712300        1.0
# 2008-08-11     0.0    24.12375  24.179700       -1.0
# 2009-03-19     1.0    13.27850  13.242200        1.0
# 2010-08-24     0.0    36.35875  36.407800       -1.0
# 2010-09-17     1.0    36.62350  36.592600        1.0
# 2011-05-11     0.0    48.92950  48.942900       -1.0
# 2011-05-12     1.0    48.98875  48.980000        1.0
# 2011-05-16     0.0    49.01875  49.019000       -1.0
# 2011-07-22     1.0    49.18600  49.115300        1.0
# 2011-12-27     0.0    55.44525  55.448800       -1.0

# %%
fig = plt.figure(figsize=(20,10))

ax1 = fig.add_subplot(111,  ylabel='Price in $')
aapl['Close'].plot(ax=ax1, color='r', lw=2.)
signals[['short_mavg', 'long_mavg']].plot(ax=ax1, lw=2.)

# Plot the buy signals
ax1.plot(signals.loc[signals.positions == 1.0].index, 
         signals.short_mavg[signals.positions == 1.0],
         '^', markersize=10, color='m')
         
# Plot the sell signals
ax1.plot(signals.loc[signals.positions == -1.0].index, 
         signals.short_mavg[signals.positions == -1.0],
         'v', markersize=10, color='k')

# %% [markdown]
# # Simple Backtester

# %%
initial_capital= float(100000.0)

# %%
positions = pd.DataFrame(index=signals.index).fillna(0.0)

# Buy a 100 shares
positions['AAPL'] = 100*signals['signal']

# Initialize the portfolio with value owned   
portfolio = positions.multiply(aapl['Close'], axis=0)

# %%
# Store the difference in shares owned 
pos_diff = positions.diff() # +100, -100, but mostly 0

# Add `holdings` to portfolio
portfolio['holdings'] = (positions.multiply(aapl['Close'], axis=0)).sum(axis=1)

# %%
# Add `cash` to portfolio
portfolio['cash'] = initial_capital - (pos_diff.multiply(aapl['Close'], axis=0)).sum(axis=1).cumsum()   

# Add `total` to portfolio
portfolio['total'] = portfolio['cash'] + portfolio['holdings']

# Add `returns` to portfolio
portfolio['returns'] = portfolio['total'].pct_change()

# %%
portfolio[35:45]
# Out:
#               AAPL  holdings      cash     total  returns
# Date
# 2006-11-20     0.0       0.0  100000.0  100000.0  0.00000
# 2006-11-21     0.0       0.0  100000.0  100000.0  0.00000
# 2006-11-22     0.0       0.0  100000.0  100000.0  0.00000
# 2006-11-24     0.0       0.0  100000.0  100000.0  0.00000
# 2006-11-27     0.0       0.0  100000.0  100000.0  0.00000
# 2006-11-28  1312.0    1312.0   98688.0  100000.0  0.00000
# 2006-11-29  1311.0    1311.0   98688.0   99999.0 -0.00001
# 2006-11-30  1309.0    1309.0   98688.0   99997.0 -0.00002
# 2006-12-01  1305.0    1305.0   98688.0   99993.0 -0.00004
# 2006-12-04  1302.0    1302.0   98688.0   99990.0 -0.00003

# %%
portfolio.tail(10)
# Out:
#               AAPL  holdings      cash     total   returns
# Date
# 2011-12-16  5443.0    5443.0   97436.0  102879.0  0.000292
# 2011-12-19  5460.0    5460.0   97436.0  102896.0  0.000165
# 2011-12-20  5656.0    5656.0   97436.0  103092.0  0.001905
# 2011-12-21  5664.0    5664.0   97436.0  103100.0  0.000078
# 2011-12-22  5694.0    5694.0   97436.0  103130.0  0.000291
# 2011-12-23  5762.0    5762.0   97436.0  103198.0  0.000659
# 2011-12-27     0.0       0.0  103244.0  103244.0  0.000446
# 2011-12-28     0.0       0.0  103244.0  103244.0  0.000000
# 2011-12-29     0.0       0.0  103244.0  103244.0  0.000000
# 2011-12-30     0.0       0.0  103244.0  103244.0  0.000000

# %%
fig = plt.figure()

ax1 = fig.add_subplot(111, ylabel='Portfolio value in $')

# Plot the equity curve in dollars
portfolio['total'].plot(ax=ax1, lw=2.)

ax1.plot(portfolio.loc[signals.positions == 1.0].index, 
         portfolio.total[signals.positions == 1.0],
         '^', markersize=10, color='m')
ax1.plot(portfolio.loc[signals.positions == -1.0].index, 
         portfolio.total[signals.positions == -1.0],
         'v', markersize=10, color='k')

# %%
# Isolate the returns of your strategy
returns = portfolio['returns']

# annualized Sharpe ratio
sharpe_ratio = np.sqrt(252) * (returns.mean() / returns.std())
sharpe_ratio # 1-2: acceptable, 2+: very good
# Out:
# 0.72629834891232536

# %% [markdown]
# ### Max drawdown

# %%
# Define a trailing 252 trading day window
window = 252

# Calculate the max drawdown in the past window days for each day 
rolling_max = aapl['Close'].rolling(window, min_periods=1).max()
daily_drawdown = aapl['Close']/rolling_max - 1.0

# Calculate the minimum (negative) daily drawdown
max_daily_drawdown = daily_drawdown.rolling(window, min_periods=1).min()

# Plot the results
daily_drawdown.plot()
max_daily_drawdown.plot()

# %%
# Get the number of days in `aapl`
days = (aapl.index[-1] - aapl.index[0]).days

# Calculate the CAGR 
cagr = ((((aapl['Close'][-1]) / aapl['Close'][1])) ** (365.0/days)) - 1
cagr
# Out:
# 0.38242871355719532
