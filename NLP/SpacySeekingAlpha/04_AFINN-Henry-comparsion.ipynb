# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from pymongo import MongoClient
from spacy.en import English

# %%
client = MongoClient('localhost', 27017)
db = client.python_import
collection = db.earnings_transcript

# %%
transcripts = pd.DataFrame(list(collection.find().limit(100)))

# %%
transcripts.head(1)
# Out:
#                         _id  date_number  \
# 0  5937dba3082789410c746a1e      1130423
#
#                                         h_tone         publishDate  \
# 0  {'positiveCount': 203, 'negativeCount': 75} 2013-04-23 21:30:07
#
#                                            qAndAText  \
# 0  Operator [Operator Instructions] We'll go firs...
#
#                                 q_and_a_h_tone  q_and_a_wordSize  \
# 0  {'positiveCount': 117, 'negativeCount': 46}              7493
#
#                                              rawText  time_number  \
# 0  US Airways Group ( LCC ) Q1 2013 Earnings Call...       213007
#
#   tradingSymbol                                                url  wordSize
# 0           AAL  https://seekingalpha.com/article/1363811-us-ai...     11310

# %%
nlp = English()

# %%
def tokenize(sent):
    return [tok.lemma_ for tok in sent if tok.pos_ in ["NOUN", "PROPN", "ADJ", "VERB"] and not tok.lemma_ == '-PRON-']

# %%
def tokenize_2(sent):
    return [str(tok).lower() for tok in sent]

# %% [markdown]
# # Load Henry Tone

# %%
henry = pd.read_excel('henry_wordlist.xlsx')
henry['Word'] = henry['Word'].str.lower()
henry.reset_index()
henry.head(5)
# Out:
#           Word  Score
# 0        below     -1
# 1    challenge     -1
# 2   challenged     -1
# 3   challenges     -1
# 4  challenging     -1

# %%
def get_first_value(dic, word):
    ser = dic[dic['Word'] == word]['Score']
    if len(ser) > 0:
        return ser.iloc[0]
    return 0

# %%
get_first_value(henry, 'good')
# Out:
# 1

# %%
get_first_value(henry, 'worse')
# Out:
# -1

# %% [markdown]
# # Load AFINN-111

# %%
afinn = pd.read_csv(filepath_or_buffer='AFINN-111.txt', sep='\t', header=None)

# %%
afinn.rename(index=str, columns={0: "Word", 1: "Score"}, inplace=True)

# %%
afinn.tail(5)
# Out:
#          Word  Score
# 2472    yucky     -2
# 2473    yummy      3
# 2474   zealot     -2
# 2475  zealots     -2
# 2476  zealous      2

# %%
get_first_value(afinn, 'shit')
# Out:
# -4

# %%
henry['Score 2'] = henry['Word'].apply(lambda row: get_first_value(afinn, row))

# %%
transcripts['NLP'] = transcripts['rawText'].apply(lambda val: nlp(val))

# %%
transcripts['tokens'] = transcripts['NLP'].apply(lambda val: tokenize(val))

# %%
from scipy.stats import itemfreq

# %%
henry['Score'] = henry['Word'].apply(lambda row: get_first_value)

# %%
def build_score_for_tokens(tokens, dictionary):
    score_pos, score_neg = 0, 0
    token_pos, token_neg = [], []
    for token in tokens:
        temp_score = get_first_value(dictionary, token)
        if temp_score > 0:
            score_pos += temp_score
            token_pos.append(token)
        elif temp_score < 0:
            score_neg += temp_score
            token_neg.append(token)
    return (score_pos, score_neg, score_pos + score_neg, itemfreq(token_pos), itemfreq(token_neg))

# %%
transcripts['Sentiment Score'] = transcripts['tokens'].apply(lambda val: build_score_for_tokens(val, afinn))

# %%
transcripts['Henry Tone'] = transcripts['tokens'].apply(lambda val: build_score_for_tokens(val, henry))

# %%
transcripts['SS Ratio'] = transcripts['Sentiment Score'].apply(lambda row: row[0]/(-row[1]))

# %%
transcripts['HTone Ratio'] = transcripts['Henry Tone'].apply(lambda row: row[0]/(-row[1]))

# %%
transcripts[['url', 'Sentiment Score', 'Henry Tone', 'h_tone', 'SS Ratio', 'HTone Ratio']]
# Out:
#                                                   url  \
# 0   https://seekingalpha.com/article/1363811-us-ai...
# 1   https://seekingalpha.com/article/1129431-apple...
# 2   https://seekingalpha.com/article/1287941-adobe...
# 3   https://seekingalpha.com/article/2711985-analo...
# 4   https://seekingalpha.com/article/2885106-autom...
# 5   https://seekingalpha.com/article/2425545-autod...
# 6   https://seekingalpha.com/article/2700495-autod...
# 7   https://seekingalpha.com/article/2957556-autod...
# 8   https://seekingalpha.com/article/3197526-autod...
# 9   https://seekingalpha.com/article/3473396-autod...
# 10  https://seekingalpha.com/article/3700786-autod...
# 11  https://seekingalpha.com/article/3933036-autod...
# 12  https://seekingalpha.com/article/3976697-autod...
# 13  https://seekingalpha.com/article/4002268-autod...
# 14  https://seekingalpha.com/article/1935441-bed-b...
# 15  https://seekingalpha.com/article/80219-ross-st...
# 16  https://seekingalpha.com/article/4027140-autod...
# 17  https://seekingalpha.com/article/4051716-autod...
# 18  https://seekingalpha.com/article/4074589-autod...
# 19  https://seekingalpha.com/article/3123336-autom...
# 20  https://seekingalpha.com/article/3377535-autom...
# 21  https://seekingalpha.com/article/3614256-autom...
# 22  https://seekingalpha.com/article/3861056-autom...
# 23  https://seekingalpha.com/article/3969404-autom...
# 24  https://seekingalpha.com/article/288456-autode...
# 25  https://seekingalpha.com/article/308199-autode...
# 26  https://seekingalpha.com/article/389481-autode...
# 27  https://seekingalpha.com/article/599311-autode...
# 28  https://seekingalpha.com/article/825501-autode...
# 29  https://seekingalpha.com/article/1012691-autod...
# ..                                                ...
# 70  https://seekingalpha.com/article/156040-autode...
# 71  https://seekingalpha.com/article/174112-autode...
# 72  https://seekingalpha.com/article/190262-autode...
# 73  https://seekingalpha.com/article/205971-autode...
# 74  https://seekingalpha.com/article/254968-autode...
# 75  https://seekingalpha.com/article/270961-autode...
# 76  https://seekingalpha.com/article/2925896-analo...
# 77  https://seekingalpha.com/article/54452-autodes...
# 78  https://seekingalpha.com/article/66284-autodes...
# 79  https://seekingalpha.com/article/3197406-analo...
# 80  https://seekingalpha.com/article/77495-autodes...
# 81  https://seekingalpha.com/article/3450146-analo...
# 82  https://seekingalpha.com/article/6280-automati...
# 83  https://seekingalpha.com/article/3711516-analo...
# 84  https://seekingalpha.com/article/9758-automati...
# 85  https://seekingalpha.com/article/14882-automat...
# 86  https://seekingalpha.com/article/3904066-analo...
# 87  https://seekingalpha.com/article/3976136-analo...
# 88  https://seekingalpha.com/article/4000375-analo...
# 89  https://seekingalpha.com/article/4025671-analo...
# 90  https://seekingalpha.com/article/185247-amazon...
# 91  https://seekingalpha.com/article/4046410-analo...
# 92  https://seekingalpha.com/article/59756-costco-...
# 93  https://seekingalpha.com/article/4077737-analo...
# 94  https://seekingalpha.com/article/19603-automat...
# 95  https://seekingalpha.com/article/1509222-adobe...
# 96  https://seekingalpha.com/article/26211-automat...
# 97  https://seekingalpha.com/article/34121-automat...
# 98  https://seekingalpha.com/article/43025-automat...
# 99  https://seekingalpha.com/article/52036-automat...
#
#                                       Sentiment Score  \
# 0   (486, -167, 319, [[ability -> 2, 1], [agree ->...
# 1   (645, -97, 548, [[ability -> 2, 1], [accomplis...
# 2   (626, -39, 587, [[adopt -> 1, 1], [advanced ->...
# 3   (622, -103, 519, [[ability -> 2, 2], [active -...
# 4   (1149, -135, 1014, [[ability -> 2, 7], [advanc...
# 5   (604, -63, 541, [[ability -> 2, 1], [accept ->...
# 6   (500, -59, 441, [[accept -> 1, 1], [active -> ...
# 7   (649, -63, 586, [[ability -> 2, 1], [accept ->...
# 8   (591, -77, 514, [[accept -> 1, 1], [adopt -> 1...
# 9   (618, -95, 523, [[accept -> 1, 1], [active -> ...
# 10  (626, -60, 566, [[accept -> 1, 2], [active -> ...
# 11  (769, -115, 654, [[ability -> 2, 5], [accept -...
# 12  (532, -51, 481, [[ability -> 2, 1], [accepted ...
# 13  (596, -62, 534, [[ability -> 2, 1], [accept ->...
# 14  (218, -26, 192, [[advantage -> 2, 1], [allow -...
# 15  (64, -21, 43, [[ability -> 2, 5], [attract -> ...
# 16  (547, -39, 508, [[ability -> 2, 3], [accept ->...
# 17  (733, -72, 661, [[ability -> 2, 3], [accept ->...
# 18  (684, -47, 637, [[ability -> 2, 5], [accept ->...
# 19  (1074, -110, 964, [[ability -> 2, 1], [accept ...
# 20  (1102, -138, 964, [[accomplish -> 2, 1], [adva...
# 21  (865, -139, 726, [[ability -> 2, 3], [advantag...
# 22  (746, -66, 680, [[ability -> 2, 2], [accept ->...
# 23  (667, -77, 590, [[ability -> 2, 7], [accomplis...
# 24  (619, -103, 516, [[ability -> 2, 5], [accepted...
# 25  (560, -56, 504, [[accepted -> 1, 1], [accompli...
# 26  (652, -48, 604, [[ability -> 2, 2], [accepted ...
# 27  (527, -67, 460, [[ability -> 2, 1], [accepted ...
# 28  (484, -110, 374, [[ability -> 2, 4], [accepted...
# 29  (584, -101, 483, [[ability -> 2, 2], [accepted...
# ..                                                ...
# 70  (459, -61, 398, [[ability -> 2, 3], [accept ->...
# 71  (338, -61, 277, [[ability -> 2, 1], [accepted ...
# 72  (523, -66, 457, [[ability -> 2, 2], [accept ->...
# 73  (548, -69, 479, [[accept -> 1, 1], [adopt -> 1...
# 74  (574, -53, 521, [[ability -> 2, 3], [accept ->...
# 75  (545, -62, 483, [[ability -> 2, 1], [accepted ...
# 76  (912, -108, 804, [[ability -> 2, 1], [active -...
# 77  (485, -50, 435, [[ability -> 2, 1], [accepted ...
# 78  (534, -59, 475, [[accepted -> 1, 1], [advanced...
# 79  (848, -136, 712, [[ability -> 2, 2], [advanced...
# 80  (678, -53, 625, [[accept -> 1, 1], [adopt -> 1...
# 81  (779, -132, 647, [[active -> 1, 1], [adequate ...
# 82  (674, -59, 615, [[ability -> 2, 2], [advantage...
# 83  (905, -126, 779, [[ability -> 2, 2], [active -...
# 84  (774, -106, 668, [[ability -> 2, 1], [active -...
# 85  (1341, -88, 1253, [[ability -> 2, 5], [accompl...
# 86  (624, -99, 525, [[ability -> 2, 1], [active ->...
# 87  (629, -98, 531, [[ability -> 2, 3], [active ->...
# 88  (900, -129, 771, [[ability -> 2, 2], [accompli...
# 89  (763, -129, 634, [[ability -> 2, 3], [advanced...
# 90  (335, -73, 262, [[ability -> 2, 2], [active ->...
# 91  (990, -75, 915, [[ability -> 2, 2], [achievabl...
# 92  (92, -29, 63, [[anticipation -> 1, 1], [benefi...
# 93  (820, -82, 738, [[ability -> 2, 2], [active ->...
# 94  (1056, -112, 944, [[ability -> 2, 2], [agree -...
# 95  (618, -42, 576, [[ability -> 2, 2], [adopt -> ...
# 96  (931, -124, 807, [[ability -> 2, 5], [apprecia...
# 97  (919, -93, 826, [[ability -> 2, 1], [advantage...
# 98  (898, -85, 813, [[ability -> 2, 1], [appreciat...
# 99  (838, -105, 733, [[ability -> 2, 1], [advantag...
#
#                                            Henry Tone  \
# 0   (135, -44, 91, [[achieve -> 1, 2], [certain ->...
# 1   (203, -20, 183, [[accomplish -> 1, 2], [achiev...
# 2   (148, -14, 134, [[achieve -> 1, 12], [beat -> ...
# 3   (215, -47, 168, [[certain -> 1, 4], [deliver -...
# 4   (347, -50, 297, [[above -> 1, 1], [achieve -> ...
# 5   (162, -15, 147, [[accomplish -> 1, 1], [certai...
# 6   (146, -20, 126, [[best -> 1, 1], [certain -> 1...
# 7   (182, -19, 163, [[beat -> 1, 1], [certain -> 1...
# 8   (147, -23, 124, [[achieve -> 1, 1], [beat -> 1...
# 9   (151, -26, 125, [[achieve -> 1, 1], [certain -...
# 10  (158, -31, 127, [[achieve -> 1, 1], [certain -...
# 11  (219, -39, 180, [[accomplish -> 1, 1], [accomp...
# 12  (144, -34, 110, [[accomplish -> 1, 1], [delive...
# 13  (192, -38, 154, [[accomplish -> 1, 1], [certai...
# 14  (76, -14, 62, [[achieve -> 1, 1], [good -> 1, ...
# 15  (26, -8, 18, [[achieve -> 1, 1], [deliver -> 1...
# 16  (167, -31, 136, [[accomplish -> 1, 1], [achiev...
# 17  (231, -20, 211, [[accomplish -> 1, 3], [achiev...
# 18  (201, -33, 168, [[accomplish -> 1, 1], [achiev...
# 19  (325, -37, 288, [[accomplish -> 1, 1], [achiev...
# 20  (300, -40, 260, [[accomplish -> 1, 1], [achiev...
# 21  (225, -41, 184, [[above -> 1, 1], [accomplishm...
# 22  (214, -29, 185, [[achieve -> 1, 3], [achieveme...
# 23  (205, -40, 165, [[accomplish -> 1, 1], [certai...
# 24  (193, -22, 171, [[achievement -> 1, 1], [beat ...
# 25  (178, -25, 153, [[accomplish -> 1, 1], [accomp...
# 26  (199, -17, 182, [[achieve -> 1, 1], [achieveme...
# 27  (181, -23, 158, [[accomplish -> 1, 2], [achiev...
# 28  (165, -38, 127, [[achieve -> 1, 2], [achieveme...
# 29  (190, -41, 149, [[achieve -> 1, 3], [certain -...
# ..                                                ...
# 70  (101, -35, 66, [[achieve -> 1, 1], [beat -> 1,...
# 71  (104, -28, 76, [[achieve -> 1, 2], [beat -> 1,...
# 72  (161, -20, 141, [[achieve -> 1, 2], [certainty...
# 73  (177, -37, 140, [[certain -> 1, 2], [certainty...
# 74  (183, -21, 162, [[accomplish -> 1, 1], [achiev...
# 75  (171, -21, 150, [[achievement -> 1, 1], [certa...
# 76  (222, -37, 185, [[achieve -> 1, 2], [better ->...
# 77  (152, -20, 132, [[deliver -> 1, 1], [exceed ->...
# 78  (205, -28, 177, [[achieve -> 1, 2], [achieveme...
# 79  (205, -33, 172, [[certain -> 1, 2], [deliver -...
# 80  (219, -20, 199, [[achieve -> 1, 1], [enjoy -> ...
# 81  (186, -51, 135, [[achieve -> 1, 1], [beat -> 1...
# 82  (231, -30, 201, [[achieve -> 1, 3], [beat -> 1...
# 83  (266, -45, 221, [[above -> 1, 1], [accomplishm...
# 84  (232, -43, 189, [[achieve -> 1, 2], [achieveme...
# 85  (385, -25, 360, [[accomplish -> 1, 1], [achiev...
# 86  (198, -55, 143, [[achieve -> 1, 2], [certain -...
# 87  (218, -32, 186, [[beat -> 1, 1], [certain -> 1...
# 88  (225, -45, 180, [[accomplish -> 1, 2], [certai...
# 89  (212, -47, 165, [[above -> 1, 1], [achieve -> ...
# 90  (109, -16, 93, [[certain -> 1, 1], [deliver ->...
# 91  (293, -22, 271, [[achieve -> 1, 4], [certain -...
# 92  (32, -11, 21, [[good -> 1, 5], [high -> 1, 2],...
# 93  (251, -22, 229, [[achieve -> 1, 2], [achieveme...
# 94  (334, -42, 292, [[above -> 1, 1], [achieve -> ...
# 95  (140, -26, 114, [[achieve -> 1, 10], [achievem...
# 96  (275, -46, 229, [[achieve -> 1, 5], [beat -> 1...
# 97  (312, -27, 285, [[above -> 1, 2], [achieve -> ...
# 98  (283, -27, 256, [[above -> 1, 1], [achieve -> ...
# 99  (261, -44, 217, [[achieve -> 1, 1], [beat -> 1...
#
#                                          h_tone   SS Ratio  HTone Ratio
# 0   {'positiveCount': 203, 'negativeCount': 75}   2.910180     3.068182
# 1   {'positiveCount': 236, 'negativeCount': 30}   6.649485    10.150000
# 2   {'positiveCount': 170, 'negativeCount': 16}  16.051282    10.571429
# 3   {'positiveCount': 248, 'negativeCount': 62}   6.038835     4.574468
# 4   {'positiveCount': 411, 'negativeCount': 59}   8.511111     6.940000
# 5   {'positiveCount': 196, 'negativeCount': 23}   9.587302    10.800000
# 6   {'positiveCount': 202, 'negativeCount': 29}   8.474576     7.300000
# 7   {'positiveCount': 238, 'negativeCount': 30}  10.301587     9.578947
# 8   {'positiveCount': 191, 'negativeCount': 38}   7.675325     6.391304
# 9   {'positiveCount': 198, 'negativeCount': 31}   6.505263     5.807692
# 10  {'positiveCount': 207, 'negativeCount': 50}  10.433333     5.096774
# 11  {'positiveCount': 299, 'negativeCount': 53}   6.686957     5.615385
# 12  {'positiveCount': 199, 'negativeCount': 47}  10.431373     4.235294
# 13  {'positiveCount': 237, 'negativeCount': 52}   9.612903     5.052632
# 14   {'positiveCount': 82, 'negativeCount': 18}   8.384615     5.428571
# 15    {'positiveCount': 27, 'negativeCount': 9}   3.047619     3.250000
# 16  {'positiveCount': 220, 'negativeCount': 42}  14.025641     5.387097
# 17  {'positiveCount': 284, 'negativeCount': 33}  10.180556    11.550000
# 18  {'positiveCount': 259, 'negativeCount': 52}  14.553191     6.090909
# 19  {'positiveCount': 367, 'negativeCount': 51}   9.763636     8.783784
# 20  {'positiveCount': 335, 'negativeCount': 53}   7.985507     7.500000
# 21  {'positiveCount': 249, 'negativeCount': 54}   6.223022     5.487805
# 22  {'positiveCount': 233, 'negativeCount': 47}  11.303030     7.379310
# 23  {'positiveCount': 232, 'negativeCount': 34}   8.662338     5.125000
# 24  {'positiveCount': 244, 'negativeCount': 43}   6.009709     8.772727
# 25  {'positiveCount': 225, 'negativeCount': 35}  10.000000     7.120000
# 26  {'positiveCount': 243, 'negativeCount': 29}  13.583333    11.705882
# 27  {'positiveCount': 229, 'negativeCount': 39}   7.865672     7.869565
# 28  {'positiveCount': 194, 'negativeCount': 49}   4.400000     4.342105
# 29  {'positiveCount': 233, 'negativeCount': 53}   5.782178     4.634146
# ..                                          ...        ...          ...
# 70  {'positiveCount': 128, 'negativeCount': 58}   7.524590     2.885714
# 71  {'positiveCount': 129, 'negativeCount': 47}   5.540984     3.714286
# 72  {'positiveCount': 214, 'negativeCount': 34}   7.924242     8.050000
# 73  {'positiveCount': 220, 'negativeCount': 50}   7.942029     4.783784
# 74  {'positiveCount': 229, 'negativeCount': 27}  10.830189     8.714286
# 75  {'positiveCount': 213, 'negativeCount': 30}   8.790323     8.142857
# 76  {'positiveCount': 261, 'negativeCount': 56}   8.444444     6.000000
# 77  {'positiveCount': 177, 'negativeCount': 31}   9.700000     7.600000
# 78  {'positiveCount': 243, 'negativeCount': 45}   9.050847     7.321429
# 79  {'positiveCount': 229, 'negativeCount': 43}   6.235294     6.212121
# 80  {'positiveCount': 262, 'negativeCount': 31}  12.792453    10.950000
# 81  {'positiveCount': 228, 'negativeCount': 58}   5.901515     3.647059
# 82  {'positiveCount': 284, 'negativeCount': 41}  11.423729     7.700000
# 83  {'positiveCount': 332, 'negativeCount': 68}   7.182540     5.911111
# 84  {'positiveCount': 310, 'negativeCount': 61}   7.301887     5.395349
# 85  {'positiveCount': 442, 'negativeCount': 40}  15.238636    15.400000
# 86  {'positiveCount': 243, 'negativeCount': 74}   6.303030     3.600000
# 87  {'positiveCount': 276, 'negativeCount': 62}   6.418367     6.812500
# 88  {'positiveCount': 264, 'negativeCount': 62}   6.976744     5.000000
# 89  {'positiveCount': 256, 'negativeCount': 70}   5.914729     4.510638
# 90  {'positiveCount': 133, 'negativeCount': 16}   4.589041     6.812500
# 91  {'positiveCount': 354, 'negativeCount': 37}  13.200000    13.318182
# 92   {'positiveCount': 35, 'negativeCount': 14}   3.172414     2.909091
# 93  {'positiveCount': 275, 'negativeCount': 29}  10.000000    11.409091
# 94  {'positiveCount': 422, 'negativeCount': 48}   9.428571     7.952381
# 95  {'positiveCount': 162, 'negativeCount': 32}  14.714286     5.384615
# 96  {'positiveCount': 326, 'negativeCount': 70}   7.508065     5.978261
# 97  {'positiveCount': 370, 'negativeCount': 40}   9.881720    11.555556
# 98  {'positiveCount': 331, 'negativeCount': 43}  10.564706    10.481481
# 99  {'positiveCount': 304, 'negativeCount': 59}   7.980952     5.931818
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Smaller sentiment score ratio

# %%
transcripts[(transcripts['SS Ratio']/transcripts['HTone Ratio'])<0.75]['url']
# Out:
# 1     https://seekingalpha.com/article/1129431-apple...
# 24    https://seekingalpha.com/article/288456-autode...
# 33    https://seekingalpha.com/article/1856531-autod...
# 35    https://seekingalpha.com/article/2221833-autod...
# 90    https://seekingalpha.com/article/185247-amazon...
# Name: url, dtype: object

# %% [markdown]
# ### Much bigger sentiment score ratio

# %%
transcripts[(transcripts['SS Ratio'] / transcripts['HTone Ratio']) > 2.5]['url']
# Out:
# 16    https://seekingalpha.com/article/4027140-autod...
# 51    https://seekingalpha.com/article/171250-automa...
# 59    https://seekingalpha.com/article/123193-autode...
# 70    https://seekingalpha.com/article/156040-autode...
# 95    https://seekingalpha.com/article/1509222-adobe...
# Name: url, dtype: object

# %% [markdown]
# ### Outlier discovery

# %%
def discovery(id_):
    positive_histo = transcripts.loc[id_]['Sentiment Score'][3]
    negative_histo = transcripts.loc[id_]['Sentiment Score'][4]
    print('========================\nSentiment positive words with counts:\n')
    print(np.array(sorted(positive_histo, key=lambda var: int(var[1]), reverse=True)))
    print('========================\nSentiment negative words with counts:\n')
    print(np.array(sorted(negative_histo, key=lambda var: int(var[1]), reverse=True)))
    
    positive_histo = transcripts.loc[id_]['Henry Tone'][3]
    negative_histo = transcripts.loc[id_]['Henry Tone'][4]
    print('========================\nHenry positive words with counts:\n')
    print(np.array(sorted(positive_histo, key=lambda var: int(var[1]), reverse=True)))
    print('========================\nHenry negative words with counts:\n')
    print(np.array(sorted(negative_histo, key=lambda var: int(var[1]), reverse=True)))

# %%
discovery(16)
# Out:
# ========================
# Sentiment positive words with counts:
#
# [['increase -> 1' '28']
#  ['thank -> 2' '27']
#  ['good -> 3' '19']
#  ['like -> 2' '14']
#  ['growth -> 2' '12']
#  ['important -> 2' '11']
#  ['big -> 1' '10']
#  ['strong -> 2' '10']
#  ['kind -> 2' '8']
#  ['reach -> 1' '8']
#  ['significant -> 1' '8']
#  ['great -> 3' '7']
#  ['positive -> 2' '7']
#  ['prepared -> 1' '7']
#  ['expand -> 1' '6']
#  ['extend -> 1' '6']
#  ['fair -> 2' '6']
#  ['pleased -> 3' '5']
#  ['want -> 1' '5']
#  ['attract -> 1' '4']
#  ['benefit -> 2' '4']
#  ['free -> 1' '4']
#  ['help -> 2' '4']
#  ['mature -> 2' '4']
#  ['share -> 1' '4']
#  ['worth -> 2' '4']
#  ['ability -> 2' '3']
#  ['agreement -> 1' '3']
#  ['highlight -> 2' '3']
#  ['interested -> 2' '3']
#  ['natural -> 1' '3']
#  ['success -> 2' '3']
#  ['active -> 1' '2']
#  ['certain -> 1' '2']
#  ['commit -> 1' '2']
#  ['confidence -> 2' '2']
#  ['confident -> 2' '2']
#  ['excited -> 3' '2']
#  ['focused -> 2' '2']
#  ['healthy -> 2' '2']
#  ['helpful -> 2' '2']
#  ['matter -> 1' '2']
#  ['meaningful -> 2' '2']
#  ['motivate -> 1' '2']
#  ['nice -> 3' '2']
#  ['opportunity -> 2' '2']
#  ['perfect -> 3' '2']
#  ['progress -> 2' '2']
#  ['responsible -> 2' '2']
#  ['accept -> 1' '1']
#  ['accomplish -> 2' '1']
#  ['adopt -> 1' '1']
#  ['advanced -> 1' '1']
#  ['advantage -> 2' '1']
#  ['agree -> 1' '1']
#  ['beautiful -> 3' '1']
#  ['chance -> 2' '1']
#  ['clear -> 1' '1']
#  ['curious -> 1' '1']
#  ['encourage -> 2' '1']
#  ['engage -> 1' '1']
#  ['fantastic -> 4' '1']
#  ['favor -> 2' '1']
#  ['fit -> 1' '1']
#  ['importance -> 2' '1']
#  ['improvement -> 2' '1']
#  ['interesting -> 2' '1']
#  ['join -> 1' '1']
#  ['love -> 3' '1']
#  ['solid -> 2' '1']
#  ['solution -> 1' '1']
#  ['straight -> 1' '1']
#  ['support -> 2' '1']
#  ['top -> 2' '1']
#  ['vision -> 1' '1']
#  ['welcome -> 2' '1']
#  ['willingness -> 2' '1']]
# ========================
# Sentiment negative words with counts:
#
# [['pay -> -1' '7']
#  ['demand -> -1' '5']
#  ['risk -> -2' '3']
#  ['cut -> -1' '2']
#  ['aggressive -> -2' '1']
#  ['apologize -> -1' '1']
#  ['challenge -> -1' '1']
#  ['confusing -> -2' '1']
#  ['difficult -> -1' '1']
#  ['errors -> -2' '1']
#  ['exaggerate -> -2' '1']
#  ['exclude -> -1' '1']
#  ['hard -> -1' '1']
#  ['leave -> -1' '1']
#  ['negative -> -2' '1']
#  ['problem -> -2' '1']
#  ['uncertain -> -1' '1']]
# ========================
# Henry positive words with counts:
#
# [['more -> 1' '30']
#  ['increase -> 1' '28']
#  ['good -> 1' '19']
#  ['grow -> 1' '14']
#  ['growth -> 1' '12']
#  ['strong -> 1' '10']
#  ['high -> 1' '8']
#  ['positive -> 1' '7']
#  ['expand -> 1' '6']
#  ['most -> 1' '5']
#  ['pleased -> 1' '5']
#  ['achieve -> 1' '3']
#  ['record -> 1' '3']
#  ['success -> 1' '3']
#  ['certain -> 1' '2']
#  ['expansion -> 1' '2']
#  ['opportunity -> 1' '2']
#  ['progress -> 1' '2']
#  ['accomplish -> 1' '1']
#  ['certainty -> 1' '1']
#  ['deliver -> 1' '1']
#  ['improvement -> 1' '1']
#  ['leader -> 1' '1']
#  ['solid -> 1' '1']]
# ========================
# Henry negative words with counts:
#
# [['decline -> -1' '9']
#  ['less -> -1' '7']
#  ['low -> -1' '3']
#  ['risk -> -1' '3']
#  ['decrease -> -1' '2']
#  ['difficulty -> -1' '2']
#  ['challenge -> -1' '1']
#  ['difficult -> -1' '1']
#  ['lower -> -1' '1']
#  ['negative -> -1' '1']
#  ['uncertain -> -1' '1']]
