# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from pymongo import MongoClient
import ystockquote

# %%
from datetime import datetime, timedelta, timezone
import pytz
import math

# %% [markdown]
# # Load transcripts

# %%
est_tz = pytz.timezone('US/Eastern')
def utc_to_est(utc_dt):
    local_dt = utc_dt.replace(tzinfo=pytz.utc).astimezone(est_tz)
    return est_tz.normalize(local_dt)

# %%
def shift_time_according_to_closing_time(dt):
    if dt.hour >= 16:
        return dt + timedelta(days=1)
    return dt

# %%
def load_and_clean_transcripts():
    client = MongoClient('localhost', 27017)
    earnings_transcript_collection = client.python_import.earnings_transcript
    
    earnings_transcript = pd.DataFrame(list(earnings_transcript_collection.find()))
    earnings_transcript.drop('_id', axis=1, inplace=True)
    earnings_transcript['shifted_publishDate'] = earnings_transcript.apply(
        lambda row: datetime.strptime(row['publishDate'], '%Y-%m-%dT%H:%M:%SZ'), axis=1
    )
    earnings_transcript['shifted_publishDate'] = earnings_transcript.apply(
        lambda row: utc_to_est(row['shifted_publishDate']), axis=1
    )
    earnings_transcript['shifted_publishDate'] = earnings_transcript.apply(
        lambda row: shift_time_according_to_closing_time(row['shifted_publishDate']), axis=1
    )
    earnings_transcript['publishDate_str'] = earnings_transcript.apply(
        lambda row: str(row['shifted_publishDate'].date()), axis=1
    )
    earnings_transcript.set_index(['tradingSymbol', 'publishDate_str'], inplace=True)
    
    return earnings_transcript

# %%
earnings_transcript = load_and_clean_transcripts()

# %%
earnings_transcript.head(2)
# Out:
#                                         publishDate  \
# tradingSymbol publishDate_str
# A             2014-11-18       2014-11-17T22:25:00Z
# AA            2014-10-09       2014-10-09T01:18:03Z
#
#                                                                        qAndAText  \
# tradingSymbol publishDate_str
# A             2014-11-18
# AA            2014-10-09       Operator [Operator instructions.] Our first qu...
#
#                                                                          rawText  \
# tradingSymbol publishDate_str
# A             2014-11-18       The following audio is from a conference call ...
# AA            2014-10-09       Alcoa (NYSE: AA ) Q3 2014 Results Earnings Con...
#
#                                                                              url  \
# tradingSymbol publishDate_str
# A             2014-11-18       https://seekingalpha.com/article/2675895-agile...
# AA            2014-10-09       https://seekingalpha.com/article/2549515-alcoa...
#
#                                     shifted_publishDate
# tradingSymbol publishDate_str
# A             2014-11-18      2014-11-18 17:25:00-05:00
# AA            2014-10-09      2014-10-09 21:18:03-04:00

# %%
earnings_transcript.tail(2)
# Out:
#                                         publishDate  \
# tradingSymbol publishDate_str
# DLPH          2017-02-02       2017-02-02T14:17:56Z
#               2017-02-02       2017-02-02T19:57:18Z
#
#                                                                        qAndAText  \
# tradingSymbol publishDate_str
# DLPH          2017-02-02
#               2017-02-02       Operator And our first question comes from the...
#
#                                                                          rawText  \
# tradingSymbol publishDate_str
# DLPH          2017-02-02       The following slide deck was published by Delp...
#               2017-02-02       Delphi Automotive Plc (NYSE: DLPH ) Q4 2016 Ea...
#
#                                                                              url  \
# tradingSymbol publishDate_str
# DLPH          2017-02-02       https://seekingalpha.com/article/4041924-delph...
#               2017-02-02       https://seekingalpha.com/article/4042152-delph...
#
#                                     shifted_publishDate
# tradingSymbol publishDate_str
# DLPH          2017-02-02      2017-02-02 09:17:56-05:00
#               2017-02-02      2017-02-02 14:57:18-05:00

# %% [markdown]
# ### Load all ticker data for transcripts

# %%
def construct_dataframe_from_stock_data(arr, ticker):
    df = pd.DataFrame(arr).transpose()
    if 'Adj Close' in df.columns:
        df['Close'] = pd.to_numeric(df['Adj Close'], errors='ignore')
    elif 'Close' in df.columns:
        df['Close'] = pd.to_numeric(df['Close'], errors='ignore')
    else:
        print('{} does not have close prices'.format(ticker))
        
    df.drop(axis=1, labels=[col for col in df.columns if col not in ['Close']], inplace=True)
    indexes = pd.MultiIndex.from_product([[ticker], df.index.values.tolist()], names=['tradingSymbol', 'publishDate_str'])
    df.set_index(indexes, inplace=True)
    
    return df

# %%
def calc_labels(df):
    df['Std Dev'] = pd.Series(data=df['Close']).rolling(window=20,center=False).std()
    df['1day return'] = df['Close'].shift(-1) - df['Close']
    df['1day pct change'] = df['1day return']/df['Close']*100
    df['5day return'] = df['Close'].shift(-5) - df['Close']
    df['5day pct change'] = df['5day return']/df['Close']*100

# %%
SPY = ystockquote.get_historical_prices('SPY', '2000-01-01', '2017-12-31')

# %%
SPY_df = construct_dataframe_from_stock_data(SPY, 'SPY')

# %%
SPY_df.head(5)
# Out:
#                                     Close
# tradingSymbol publishDate_str
# SPY           2000-01-03       105.366938
#               2000-01-04       101.246443
#               2000-01-05       101.427563
#               2000-01-06        99.797478
#               2000-01-07       105.593338

# %%
calc_labels(SPY_df)
SPY_df.dropna(inplace=True)

# %%
SPY_df.head()
# Out:
#                                     Close   Std Dev  1day return  \
# tradingSymbol publishDate_str
# SPY           2000-01-31       101.110602  2.375208     0.996164
#               2000-02-01       102.106766  2.346908     0.090560
#               2000-02-02       102.197326  2.313233     1.539526
#               2000-02-03       103.736852  2.271400    -0.430195
#               2000-02-04       103.306657  2.105601    -0.158447
#
#                                1day pct change  5day return  5day pct change
# tradingSymbol publishDate_str
# SPY           2000-01-31              0.985222     2.037608         2.015227
#               2000-02-01              0.088691     2.445129         2.394679
#               2000-02-02              1.506425     0.158448         0.155041
#               2000-02-03             -0.414698    -1.177285        -1.134876
#               2000-02-04             -0.153375    -2.829977        -2.739395

# %%
tickers = earnings_transcript.index.levels[0]
all_stocks = None
try:
    all_stocks = pd.read_pickle('all_stocks.pkl')
except:
    pass

print('Downloading missing stock data')

for ticker in tickers:
    if (all_stocks is not None) and (ticker in all_stocks.index):
        continue
    try:
        stocks = ystockquote.get_historical_prices(ticker, '2000-01-01', '2017-12-31')
    except:
        print('{} is not available on Yahoo'.format(ticker))
        continue
    print('{} ticker has {} long list'.format(ticker, len(stocks)))
    
    df = construct_dataframe_from_stock_data(stocks, ticker)
    calc_labels(df)
    df.dropna(inplace=True)
    
    SPY_df.index.set_levels([[ticker], SPY_df.index.levels[1]], inplace=True)
    
    df['1day relative pct change'] = df['1day pct change'] - SPY_df['1day pct change']
    df['5day relative pct change'] = df['5day pct change'] - SPY_df['5day pct change']
    
    if all_stocks is None:
        all_stocks = df
    else:
        all_stocks = all_stocks.append(df)
        
all_stocks.to_pickle('all_stocks.pkl')
# Out:
# Downloading missing stock data
# A ticker has 4349 long list
# AA ticker has 4349 long list
# AAN ticker has 4349 long list
# AAON ticker has 4349 long list
# AAP ticker has 3871 long list
# AAPL ticker has 4349 long list
# AAT ticker has 1574 long list
# AAWW ticker has 2877 long list
# ABAX ticker has 4349 long list
# ABBV ticker has 1080 long list
# ABC ticker has 4349 long list
# ABCB ticker has 4349 long list
# ABG ticker has 3795 long list
# ABM ticker has 4349 long list
# ABT ticker has 4349 long list
# ACAT ticker has 4320 long list
# ACC ticker has 3190 long list
# ACE is not available on Yahoo
# ACET ticker has 4349 long list
# ACIW ticker has 4349 long list
# ACM ticker has 2502 long list
# ACN ticker has 3960 long list
# ACOR ticker has 2814 long list
# ACT is not available on Yahoo
# ACXM ticker has 4349 long list
# ADBE ticker has 4349 long list
# ADC ticker has 4349 long list
# ADI ticker has 4349 long list
# ADM ticker has 4349 long list
# ADNT ticker has 124 long list
# ADP ticker has 4349 long list
# ADPT ticker has 708 long list
# ADS ticker has 3983 long list
# ADSK ticker has 4349 long list
# ADTN ticker has 4349 long list
# AEE ticker has 4349 long list
# AEGN ticker has 4349 long list
# AEIS ticker has 4349 long list
# AEL ticker has 3364 long list
# AEO ticker has 4349 long list
# AEP ticker has 4349 long list
# AES ticker has 4349 long list
# AET ticker has 4349 long list
# AF ticker has 4349 long list
# AFAM ticker has 4349 long list
# AFG ticker has 4349 long list
# AFL ticker has 4349 long list
# AGCO ticker has 4349 long list
# AGYS ticker has 4349 long list
# AHL ticker has 3363 long list
# AHS ticker has 3767 long list
# AIG ticker has 4349 long list
# AIN ticker has 4349 long list
# AIR ticker has 4349 long list
# AIRM ticker has 4349 long list
# AIT ticker has 4349 long list
# AIV ticker has 4349 long list
# AIZ ticker has 3322 long list
# AJG ticker has 4349 long list
# AJRD ticker has 4349 long list
# AKAM ticker has 4349 long list
# AKR ticker has 4349 long list
# AKRX ticker has 3702 long list
# AKS ticker has 4349 long list
# ALB ticker has 4349 long list
# ALE ticker has 4349 long list
# ALEX ticker has 1217 long list
# ALG ticker has 4349 long list
# ALGN ticker has 4078 long list
# ALGT ticker has 2605 long list
# ALK ticker has 4349 long list
# ALL ticker has 4349 long list
# ALLE ticker has 858 long list
# ALOG ticker has 4349 long list
# ALTR is not available on Yahoo
# ALXN ticker has 4349 long list
# AMAG ticker has 4349 long list
# AMAT ticker has 4349 long list
# AMCX ticker has 1468 long list
# AMD ticker has 4349 long list
# AME ticker has 4349 long list
# AMED ticker has 4349 long list
# AMGN ticker has 4349 long list
# AMP ticker has 2916 long list
# AMPH ticker has 708 long list
# AMRI ticker has 4349 long list
# AMSF ticker has 2870 long list
# AMSG ticker has 4257 long list
# AMT ticker has 4349 long list
# AMWD ticker has 4349 long list
# AMZN ticker has 4349 long list
# AN ticker has 4349 long list
# ANDE ticker has 4349 long list
# ANF ticker has 4349 long list
# ANGO ticker has 3242 long list
# ANIK ticker has 4349 long list
# ANIP ticker has 4263 long list
# ANSS ticker has 4349 long list
# AON ticker has 4349 long list
# AOS ticker has 4349 long list
# APA ticker has 4349 long list
# APC ticker has 4349 long list
# APD ticker has 4349 long list
# APEI ticker has 2374 long list
# APH ticker has 4349 long list
# APOG ticker has 4349 long list
# APOL ticker has 4298 long list
# ARCB ticker has 4349 long list
# ARE ticker has 4349 long list
# AROC ticker has 2431 long list
# ARRS ticker has 4349 long list
# ARW ticker has 4349 long list
# ASB ticker has 4349 long list
# ASGN ticker has 4349 long list
# ASH ticker has 4349 long list
# ASNA ticker has 4349 long list
# ASTE ticker has 4349 long list
# ATI ticker has 4349 long list
# ATNI ticker has 4349 long list
# ATO ticker has 4349 long list
# ATR ticker has 4349 long list
# ATU ticker has 4209 long list
# ATVI ticker has 4349 long list
# ATW ticker has 4349 long list
# AVA ticker has 4349 long list
# AVAV ticker has 2577 long list
# AVB ticker has 4349 long list
# AVD ticker has 4349 long list
# AVP ticker has 4349 long list
# AVT ticker has 4349 long list
# AVY ticker has 4349 long list
# AWK ticker has 2262 long list
# CRL ticker has 4229 long list
# CRM ticker has 3227 long list
# CROX ticker has 2816 long list
# CRR ticker has 4349 long list
# CRS ticker has 4349 long list
# CRUS ticker has 4349 long list
# CRVL ticker has 4349 long list
# CRY ticker has 4349 long list
# CRZO ticker has 4349 long list
# CSAL ticker has 468 long list
# CSCO ticker has 4349 long list
# CSGS ticker has 4349 long list
# CSL ticker has 4349 long list
# CSRA ticker has 356 long list
# CST ticker has 1008 long list
# CSX ticker has 4349 long list
# CTAS ticker has 4349 long list
# CTL ticker has 4349 long list
# CTLT ticker has 683 long list
# CTRE ticker has 727 long list
# CTS ticker has 4349 long list
# CTSH ticker has 4349 long list
# CTXS ticker has 4349 long list
# CUB ticker has 4349 long list
# CUBI ticker has 1281 long list
# CUZ ticker has 4349 long list
# CVBF ticker has 4349 long list
# CVCO ticker has 3473 long list
# CVG ticker has 4349 long list
# CVLT ticker has 2659 long list
# CVS ticker has 4349 long list
# CVX ticker has 4349 long list
# CW ticker has 4349 long list
# CWT ticker has 4349 long list
# CXO ticker has 2443 long list
# CXW ticker has 4349 long list
# CY ticker has 4349 long list
# CYH ticker has 4239 long list
# CYNO ticker has 2839 long list
# D ticker has 4349 long list
# DAKT ticker has 4349 long list
# DAL ticker has 2507 long list
# DAN ticker has 2339 long list
# DAR ticker has 4349 long list
# DBD ticker has 4349 long list
# DCI ticker has 4349 long list
# DCT ticker has 2602 long list
# DD ticker has 4349 long list
# DDD ticker has 4349 long list
# DE ticker has 4349 long list
# DECK ticker has 4349 long list
# DEI ticker has 2636 long list
# DEL ticker has 4349 long list
# DEPO ticker has 4349 long list
# DF ticker has 4349 long list
# DFS ticker has 2478 long list
# DG ticker has 1867 long list
# DGII ticker has 4349 long list
# DGX ticker has 4349 long list
# DHI ticker has 4349 long list
# DHR ticker has 4349 long list
# DHX ticker has 2449 long list
# DIN ticker has 4349 long list
# DIOD ticker has 4349 long list
# DIS ticker has 4349 long list
# DISCA ticker has 2964 long list
# DKS ticker has 3650 long list
# DLPH ticker has 1360 long list

# %%
all_stocks.sample(20)
# Out:
#                                     Close   Std Dev  1day return  \
# tradingSymbol publishDate_str
# AGCO          2006-11-02        27.076669  1.075552    -0.163634
# CY            2008-01-30         3.680734  0.898391    -0.001740
# AA            2014-12-24        36.984048  2.273917     0.117262
# AKR           2004-11-08         8.974366  0.152904     0.029716
# APOG          2002-02-12         8.974893  0.854092     0.045481
# ANGO          2010-08-06        16.000000  0.340193     0.469999
# AMZN          2012-02-03       187.679993  6.342532    -4.539994
# ATW           2000-08-09         9.791444  0.438681    -0.163196
# DECK          2012-08-23        49.049999  3.459024     0.490002
# ALG           2007-08-15        22.505500  0.499285    -0.758407
# AEO           2012-11-28        17.965574  0.722719     0.276792
# ANIK          2007-08-30        18.250000  0.888982    -0.020000
# CVLT          2010-08-06        19.830000  1.236701     0.610001
# ANGO          2010-08-30        15.140000  0.353825     0.080000
# DISCA         2011-08-09        19.008686  0.962403    -0.531425
# AKRX          2011-10-13         8.880000  0.609232     0.000000
# AMAT          2002-01-16        16.583417  0.987657     0.019956
# DAN           2013-02-19        16.299595  0.462385    -0.531302
# DF            2002-07-18         9.938295  0.728546    -0.513215
# ARW           2011-06-02        42.389999  1.325040    -1.309997
#
#                                1day pct change  5day return  5day pct change  \
# tradingSymbol publishDate_str
# AGCO          2006-11-02             -0.604336     2.185001         8.069682
# CY            2008-01-30             -0.047273    -0.187070        -5.082410
# AA            2014-12-24              0.317061     0.257975         0.697530
# AKR           2004-11-08              0.331121     0.059433         0.662253
# APOG          2002-02-12              0.506758    -0.197084        -2.195948
# ANGO          2010-08-06              2.937494    -0.190000        -1.187500
# AMZN          2012-02-03             -2.419008    -2.140000        -1.140239
# ATW           2000-08-09             -1.666720     0.311541         3.181768
# DECK          2012-08-23              0.998985    -0.029999        -0.061160
# ALG           2007-08-15             -3.369874    -0.438596        -1.948839
# AEO           2012-11-28              1.540680     0.423839         2.359173
# ANIK          2007-08-30             -0.109589    -0.340000        -1.863014
# CVLT          2010-08-06              3.076152    -0.580000        -2.924861
# ANGO          2010-08-30              0.528402     0.090000         0.594452
# DISCA         2011-08-09             -2.795696     1.134390         5.967745
# AKRX          2011-10-13              0.000000    -0.840000        -9.459459
# AMAT          2002-01-16              0.120337    -0.606662        -3.658245
# DAN           2013-02-19             -3.259602    -0.711565        -4.365538
# DF            2002-07-18             -5.164015     0.235625         2.370880
# ARW           2011-06-02             -3.090344    -2.599998        -6.133517
#
#                                1day relative pct change  \
# tradingSymbol publishDate_str
# AGCO          2006-11-02                      -0.428868
# CY            2008-01-30                      -1.870705
# AA            2014-12-24                      -0.005410
# AKR           2004-11-08                       0.527520
# APOG          2002-02-12                      -0.555444
# ANGO          2010-08-06                       2.403640
# AMZN          2012-02-03                      -2.352116
# ATW           2000-08-09                      -1.179194
# DECK          2012-08-23                       0.394697
# ALG           2007-08-15                      -4.121443
# AEO           2012-11-28                       1.074126
# ANIK          2007-08-30                      -1.094880
# CVLT          2010-08-06                       2.542299
# ANGO          2010-08-30                       0.528402
# DISCA         2011-08-09                       1.622080
# AKRX          2011-10-13                      -1.709399
# AMAT          2002-01-16                      -0.633074
# DAN           2013-02-19                      -2.013271
# DF            2002-07-18                      -1.644649
# ARW           2011-06-02                      -2.095888
#
#                                5day relative pct change
# tradingSymbol publishDate_str
# AGCO          2006-11-02                       7.046145
# CY            2008-01-30                      -3.703713
# AA            2014-12-24                       1.823782
# AKR           2004-11-08                      -1.021525
# APOG          2002-02-12                      -1.745862
# ANGO          2010-08-06                       2.442718
# AMZN          2012-02-03                      -1.006455
# ATW           2000-08-09                       2.376342
# DECK          2012-08-23                       0.059697
# ALG           2007-08-15                      -5.926435
# AEO           2012-11-28                       2.330902
# ANIK          2007-08-30                      -1.808284
# CVLT          2010-08-06                       0.705356
# ANGO          2010-08-30                      -3.517221
# DISCA         2011-08-09                       4.171701
# AKRX          2011-10-13                     -10.413738
# AMAT          2002-01-16                      -4.331887
# DAN           2013-02-19                      -2.257874
# DF            2002-07-18                       6.698900
# ARW           2011-06-02                      -4.364747

# %%
all_stocks.tail(5)
# Out:
#                                    Close   Std Dev  1day return  \
# tradingSymbol publishDate_str
# DLPH          2017-04-03       78.250000  1.963170    -2.269997
#               2017-04-04       75.980003  1.962236    -0.890007
#               2017-04-05       75.089996  2.104154     0.030007
#               2017-04-06       75.120003  2.208314     0.019996
#               2017-04-07       75.139999  2.350559     0.390000
#
#                                1day pct change  5day return  5day pct change  \
# tradingSymbol publishDate_str
# DLPH          2017-04-03             -2.900955    -2.720001        -3.476040
#               2017-04-04             -1.171370    -1.069999        -1.408264
#               2017-04-05              0.039961    -0.809997        -1.078702
#               2017-04-06              0.026619    -1.370003        -1.823753
#               2017-04-07              0.519031    -0.430000        -0.572265
#
#                                1day relative pct change  \
# tradingSymbol publishDate_str
# DLPH          2017-04-03                      -2.964692
#               2017-04-04                      -0.874106
#               2017-04-05                      -0.241154
#               2017-04-06                       0.128558
#               2017-04-07                       0.459508
#
#                                5day relative pct change
# tradingSymbol publishDate_str
# DLPH          2017-04-03                      -3.480286
#               2017-04-04                      -1.229906
#               2017-04-05                      -0.759254
#               2017-04-06                      -0.579271
#               2017-04-07                      -0.304412

# %% [markdown]
# # Merge transcripts with stock data

# %%
merged_data = earnings_transcript.merge(all_stocks, left_index=True, right_index=True)

# %%
merged_data.sample(5)
# Out:
#                                         publishDate  \
# tradingSymbol publishDate_str
# APA           2011-11-04       2011-11-04T01:30:12Z
# DHI           2014-07-24       2014-07-24T13:55:00Z
# ATI           2016-10-25       2016-10-25T17:43:12Z
# AKAM          2017-03-31       2017-03-31T17:04:36Z
# ADI           2006-02-16       2006-02-16T18:12:15Z
#
#                                                                        qAndAText  \
# tradingSymbol publishDate_str
# APA           2011-11-04       Operator [Operator Instructions] Your first qu...
# DHI           2014-07-24
# ATI           2016-10-25       Operator Sure. We will now begin the question-...
# AKAM          2017-03-31
# ADI           2006-02-16
#
#                                                                          rawText  \
# tradingSymbol publishDate_str
# APA           2011-11-04       Apache (NYSE: APA ) Q3 2011 Earnings Call Nove...
# DHI           2014-07-24       The following audio is from a conference call ...
# ATI           2016-10-25       Allegheny Technologies, Inc. (NYSE: ATI ) Q3 2...
# AKAM          2017-03-31       The following slide deck was published by Akam...
# ADI           2006-02-16       Analog Devices Inc. (NYSE: ADI )   Q1 2006 Ear...
#
#                                                                              url  \
# tradingSymbol publishDate_str
# APA           2011-11-04       https://seekingalpha.com/article/305203-apache...
# DHI           2014-07-24       https://seekingalpha.com/article/2336945-q3-20...
# ATI           2016-10-25       https://seekingalpha.com/article/4014658-alleg...
# AKAM          2017-03-31       https://seekingalpha.com/article/4059499-akama...
# ADI           2006-02-16       https://seekingalpha.com/article/6884-analog-d...
#
#                                     shifted_publishDate      Close   Std Dev  \
# tradingSymbol publishDate_str
# APA           2011-11-04      2011-11-04 21:30:12-04:00  93.375693  5.321505
# DHI           2014-07-24      2014-07-24 09:55:00-04:00  21.286876  0.635615
# ATI           2016-10-25      2016-10-25 13:43:12-04:00  15.120000  0.734599
# AKAM          2017-03-31      2017-03-31 13:04:36-04:00  59.700001  1.307269
# ADI           2006-02-16      2006-02-16 13:12:15-05:00  29.059107  0.628357
#
#                                1day return  1day pct change  5day return  \
# tradingSymbol publishDate_str
# APA           2011-11-04          1.183508         1.267469     4.202840
# DHI           2014-07-24         -0.320176        -1.504100    -1.203086
# ATI           2016-10-25         -0.850000        -5.621693    -1.750000
# AKAM          2017-03-31         -1.600003        -2.680072    -1.600003
# ADI           2006-02-16         -0.580009        -1.995963    -0.806209
#
#                                5day pct change  1day relative pct change  \
# tradingSymbol publishDate_str
# APA           2011-11-04              4.501000                  0.645858
# DHI           2014-07-24             -5.651773                 -1.035944
# ATI           2016-10-25            -11.574074                 -5.420922
# AKAM          2017-03-31             -2.680072                 -2.506150
# ADI           2006-02-16             -2.774376                 -1.724977
#
#                                5day relative pct change
# tradingSymbol publishDate_str
# APA           2011-11-04                       3.560611
# DHI           2014-07-24                      -2.852882
# ATI           2016-10-25                     -10.098609
# AKAM          2017-03-31                      -2.451003
# ADI           2006-02-16                      -2.967935

# %%
merged_data = merged_data[merged_data['rawText'].apply(len) > 5000]

# %%
merged_data.to_pickle('merged_data_pct_change.pkl')
